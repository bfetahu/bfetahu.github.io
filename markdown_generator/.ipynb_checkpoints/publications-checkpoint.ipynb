# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat /Users/bfetahu/Downloads/citations.csv
# Out:
# ﻿Authors,Title,Publication,Volume,Number,Pages,Year,Publisher
# "Nunes, Bernardo Pereira; Dietze, Stefan; Casanova, Marco Antonio; Kawase, Ricardo; Fetahu, Besnik; Nejdl, Wolfgang; ",Combining a co-occurrence-based and a semantic measure for entity linking,Extended Semantic Web Conference,,,548-562,2013,Springer Berlin Heidelberg
# "Taibi, Davide; Fetahu, Besnik; Dietze, Stefan; ",Towards integration of web data into a coherent educational data graph,Proceedings of the 22nd International Conference on World Wide Web,,,419-424,2013,ACM
# "Nunes, Bernardo Pereira; Mera, Alexander; Casanova, Marco Antonio; Fetahu, Besnik; Leme, Luiz André P Paes; Dietze, Stefan; ",Complex matching of rdf datatype properties,International Conference on Database and Expert Systems Applications,,,195-208,2013,"Springer, Berlin, Heidelberg"
# "Nunes, B Pereira; Fetahu, Besnik; Casanova, Marco Antonio; ",Cite4me: Semantic retrieval and analysis of scientific publications,LAK (Data Challenge),974,,,2013,
# "Fetahu, Besnik; Dietze, Stefan; Nunes, Bernardo Pereira; Taibi, Davide; Casanova, Marco Antonio; ",Generating structured Profiles of Linked Data Graphs.,International Semantic Web Conference (Posters & Demos),,,113-116,2013,
# "Nunes, Bernardo Pereira; Fetahu, Besnik; Dietze, Stefan; Casanova, Marco A; ",Cite4Me: A Semantic Search and Retrieval Web Application for Scientific Publications,"Proceedings of the ISWC 2013 Posters & Demonstrations Track, Sydney, Australia.",,,,2013,
# "Nunes, Bernardo Pereira; Kawase, Ricardo; Fetahu, Besnik; Dietze, Stefan; Casanova, Marco A; Maynard, Diana; ",Interlinking documents based on semantic graphs,Procedia Computer Science,22,,231-240,2013,Elsevier
# "Fetahu, Besnik; Dietze, Stefan; Nunes, Bernardo Pereira; Antonio, Marco; ",A Scalable Approach for Efficiently Generating Structured Dataset Topic Profiles,In Proceedings of the 11th Extended Semantic Web Conference,,,,2014,Springer
# "Fetahu, Besnik; Pereira Nunes, Bernardo; Dietze, Stefan; ",Towards focused knowledge extraction: query-based extraction of structured summaries,Proceedings of the 22nd International Conference on World Wide Web,,,77-78,2013,
# "Fetahu, Besnik; Nunes, Bernardo Pereira; Dietze, Stefan; ",Summaries on the fly: Query-based extraction of structured knowledge from web documents,International Conference on Web Engineering,,,249-264,2013,Springer Berlin Heidelberg
# "Fetahu, Besnik; Schenkel, Ralf; ",Retrieval evaluation on focused tasks,Proceedings of the 35th international ACM SIGIR conference on Research and development in information retrieval,,,1135-1136,2012,ACM
# "Fetahu, Besnik; Dietze, Stefan; Nunes, Bernardo Pereira; Casanova, Marco Antonio; Taibi, Davide; Nejdl, Wolfgang; ",What’s all the Data about?-Creating Structured Profiles of Linked Data on the Web,Proceedings of the companion publication of the 23rd international conference on World wide web companion,,,261-262,2014,International World Wide Web Conferences Steering Committee
# "Nunes, Bernardo Pereira; Kawase, Ricardo; Fetahu, Besnik; Casanova, Marco A; de Campos, Gilda Helena B; ",Educational forums at a glance: Topic extraction and selection,International Conference on Web Information Systems Engineering,,,351-364,2014,"Springer, Cham"
# "Nunes, Bernardo Pereira; Mera, Alexander; Kawase, Ricardo; Fetahu, Besnik; Casanova, Marco A; Campos, Gilda Helena B de; ",A Topic Extraction Process for Online Forums,"Advanced Learning Technologies (ICALT), 2014 IEEE 14th International Conference on",,,541-543,2014,IEEE
# "Fetahu, Besnik; Gadiraju, Ujwal; Dietze, Stefan; ",Crawl Me Maybe: Iterative Linked Dataset Preservation.,International Semantic Web Conference (Posters & Demos),,,433-436,2014,
# "Taibi, Davide; Dietze, Stefan; Fetahu, Besnik; Fulantelli, Giovanni; ",Exploring type-specific topic profiles of datasets: a demo for educational linked data,,,,,2011,
# "Nunes, Bernardo Pereira; Fetahu, Besnik; Kawase, Ricardo; Dietze, Stefan; Casanova, Marco Antonio; Maynard, Diana; ",Interlinking Documents Based on Semantic Graphs with an Application,Knowledge-Based Information Systems in Practice,,,139-155,2015,Springer International Publishing
# "Taibi, Davide; Chawla, Saniya; Dietze, Stefan; Marenzi, Ivana; Fetahu, Besnik; ",Exploring TED talks as linked data for education,British Journal of Educational Technology,46,5,1092-1096,2015,
# "Taibi, Davide; Fulantelli, Giovanni; Dietze, Stefan; Fetahu, Besnik; ",Towards Analysing the Scope and Coverage of Educational Linked Data on the Web,,,,,,
# "Fetahu, Besnik; Gadiraju, Ujwal; Dietze, Stefan; ",Improving entity retrieval on structured data,International Semantic Web Conference,,,474-491,2015,Springer International Publishing
# "Fetahu, Besnik; Anand, Abhijit; Anand, Avishek; ",How much is Wikipedia lagging behind news?,Proceedings of the ACM Web Science Conference,,,1-9,2015,
# "Fetahu, Besnik; Markert, Katja; Anand, Avishek; ",Automated News Suggestions for Populating Wikipedia Entity Pages,Proceedings of the 24th ACM International on Conference on Information and Knowledge Management,,,323-332,2015,ACM
# "Gadiraju, Ujwal; Siehndel, Patrick; Fetahu, Besnik; Kawase, Ricardo; ",Breaking Bad: Understanding Behavior of Crowd Workers in Categorization Microtasks,Proceedings of the 26th ACM Conference on Hypertext & Social Media,,,33-38,2015,ACM
# "Gadiraju, Ujwal; Fetahu, Besnik; Kawase, Ricardo; ",Training workers for improving performance in crowdsourcing microtasks,Design for Teaching and Learning in a Networked World,,,100-114,2015,"Springer, Cham"
# "Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Dietze, Stefan; ",Adaptive Focused Crawling of Linked Data,International Conference on Web Information Systems Engineering,,,554-569,2015,Springer International Publishing
# "Fetahu, Besnik; Dietze, Stefan; Nunes, Bernardo Pereira; Taibi, Davide; Casanova, Marco Antonio; ",Profiling of Linked Datasets using Structured Descriptions,The 12th International Semantic Web Conference (ISWC2013),,,,2013,
# "Taibi, Davide; Fulantelli, Giovanni; Dietze, Stefan; Fetahu, Besnik; ",Educational Linked Data on the Web-Exploring and Analysing the Scope and Coverage,Open Data for Education,,,16-37,2016,Springer International Publishing
# "Yu, Ran; Gadiraju, Ujwal; Zhu, Xiaofei; Fetahu, Besnik; Dietze, Stefan; ",Towards entity summarisation on structured web markup,European Semantic Web Conference,,,69-73,2016,"Springer, Cham"
# "Fetahu, Besnik; Markert, Katja; Nejdl, Wolfgang; Anand, Avishek; ",Finding News Citations for Wikipedia,Proceedings of the 25th ACM International on Conference on Information and Knowledge Management,,,337-346,2016,ACM
# "Yu, Ran; Fetahu, Besnik; Gadiraju, Ujwal; Dietze, Stefan; ",A Survey on Challenges for Entity Retrieval in Web Markup Data,CEUR Workshop Proceedings,1690,,,2016,
# "Gadiraju, Ujwal; Fetahu, Besnik; Hube, Christoph; ",Crystal clear or very vague? Effects of task clarity in the microtask crowdsourcing ecosystem,"1st International Workshop on Weaving Relations of Trust in Crowd Work: Transparency and Reputation Across Platforms, Co-located With the 8th International ACM Web Science Conference",,,,2016,
# "Taibi, Davide; Fulantelli, Giovanni; Dietze, Stefan; Fetahu, Besnik; ",A Linked Data approach to evaluate Open Education Resources,Proceedings of the 2013 International Conference on Education and Modern Educational Technologies,,,154-157,2013,
# "Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Dietze, Stefan; ",FuseM: query-centric data fusion on structured web markup,2017 IEEE 33rd International Conference on Data Engineering (ICDE),,,179-182,2017,IEEE
# "Fetahu, Besnik; Markert, Katja; Anand, Avishek; ",Fine Grained Citation Span for References in Wikipedia,arXiv preprint arXiv:1707.07278,,,,2017,
# "Gadiraju, Ujwal; Fetahu, Besnik; Kawase, Ricardo; Siehndel, Patrick; Dietze, Stefan; ",Using worker self-assessments for competence-based pre-selection in crowdsourcing microtasks,ACM Transactions on Computer-Human Interaction (TOCHI),24,4,1-26,2017,"ACM New York, NY, USA"
# "d'Aquin, Mathieu; Adamou, Alessandro; Dietze, Stefan; Fetahu, Besnik; Gadiraju, Ujwal; Hasani-Mavriqi, Ilire; Holtz, Peter; Kimmerle, Joachim; Kowald, Dominik; Lex, Elisabeth; ",AFEL: Towards Measuring Online Activities Contributions to Self-directed Learning.,ARTEL@ EC-TEL,,,,2017,
# "Yu, Ran; Fetahu, Besnik; Gadiraju, Ujwal; Dietze, Stefan; ",A Survey on Challenges in Web Markup Data for Entity Retrieval.,International Semantic Web Conference (Posters & Demos),,,17-21,2016,
# "Hube, Christoph; Jäschke, Robert; Fetahu, Besnik; ",Towards Bias Detection in Online Text Corpora,Jo Bates Paul D. Clough Robert Jäschke,,,19,,
# "Hube, Christoph; Fetahu, Besnik; ",Detecting biased statements in wikipedia,Companion Proceedings of the The Web Conference 2018,,,1779-1786,2018,International World Wide Web Conferences Steering Committee
# "Lyu, Lijun; Fetahu, Besnik; ",Real-time Event-based News Suggestion for Wikipedia Pages from News Streams,Companion Proceedings of the The Web Conference 2018,,,1793-1799,2018,International World Wide Web Conferences Steering Committee
# "Holtz, Peter; Fetahu, Besnik; Kimmerle, Joachim; ",Effects of contributor experience on the quality of health-related Wikipedia articles,Journal of medical Internet research,20,5,e171,2018,"JMIR Publications Inc., Toronto, Canada"
# "Chawla, S; Taibi, D; Dietze, S; Marenzi, I; Fetahu, B; ",Exploring TED talks as linked data for education,,,,,2015,British Journal of Educational Technology
# "Yenikent, Seren; Buttliere, Brett; Fetahu, Besnik; Kimmerle, Joachim; ",Wikipedia article measures in relation to content characteristics of lead sections,7th International Workshop on Learning and Education with Web Data (# LILE2018) in conjunction with the 10th ACM Conference on Web Science (WebSci18),,,5-8,2018,"Association for Computing Machinery Amsterdam, The Netherlands"
# "Fetahu, Besnik; ",Approaches for Enriching and Improving Textual Knowledge Bases,arXiv preprint arXiv:1804.07583,,,,2018,
# "Hube, Christoph; Fetahu, Besnik; Gadiraju, Ujwal; ",LimitBias! Measuring Worker Biases in the Crowdsourced Collection of Subjective Judgments,,,,,2018,
# "Hube, Christoph; Fetahu, Besnik; ",Neural Based Statement Classification for Biased Language,Proceedings of the Twelfth ACM International Conference on Web Search and Data Mining,,,195-203,2019,ACM
# "Hube, Christoph; Fetahu, Besnik; Gadiraju, Ujwal; ",Understanding and mitigating worker biases in the crowdsourced collection of subjective judgments,Proceedings of the 2019 CHI Conference on Human Factors in Computing Systems,,,1-12,2019,
# "Fetahu, Besnik; Anand, Avishek; Koutraki, Maria; ",TableNet: An Approach for Determining Fine-grained Relations for Wikipedia Tables,The World Wide Web Conference,,,2736-2742,2019,
# "Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Lehmberg, Oliver; Ritze, Dominique; Dietze, Stefan; ",KnowMore–knowledge base augmentation with structured web markup,Semantic Web,10,1,159-180,2019,IOS Press
# "Fetahu, Besnik; ",Approaches for enriching and improving textual knowledge bases,,,,,2017,Hannover: Gottfried Wilhelm Leibniz Universität Hannover
# "d’Aquin, Mathieu; Alessandro Adamou, A; Dietze, Stefan; Fetahu, Besnik; ",The LinkedUp Data Catalogue: A Meta-Dataset of Linked Datasets in the Education Domain,"Semantic Web–Interoperability, Usability, Applicability",,,,2014,
# "Redi, Miriam; Fetahu, Besnik; Morgan, Jonathan; Taraborelli, Dario; ",Citation Needed: A Taxonomy and Algorithmic Assessment of Wikipedia's Verifiability,The World Wide Web Conference,,,1567-1578,2019,ACM
# "Holtz, P; Fetahu, B; Kimmerle, J; ",Explore our sister journals here.,J Med Internet Res,20,5,e171,2018,
# "Gottschalk, Simon; Tempelmeier, Nicolas; Kniesel, Günter; Iosifidis, Vasileios; Fetahu, Besnik; Demidova, Elena; ",Simple-ML: Towards a Framework for Semantic Data Analytics Workflows,International Conference on Semantic Systems,,,359-366,2019,"Springer, Cham"
# "Gottschalk, Simon; Tempelmeier, Nicolas; Kniesel, Günter; Iosifidis, Vasileios; Fetahu, Besnik; Demidova, Elena; ",Simple-ML: Towards a Framework for Semantic Data Analytics Workflows,International Conference on Semantic Systems,,,359-366,2019,"Springer, Cham"
# "Hube, Christoph; Idahl, Maximilian; Fetahu, Besnik; ",Debiasing Word Embeddings from Sentiment Associations in Names,Proceedings of the 13th International Conference on Web Search and Data Mining,,,259-267,2020,
# "Iosifidis, Vasileios; Fetahu, Besnik; Ntoutsi, Eirini; ",FAE: A Fairness-Aware Ensemble Framework,2019 IEEE International Conference on Big Data (Big Data),,,1375-1380,2019,IEEE
# "Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Lehmberg, Oliver; Ritze, Dominique; Dietze, Stefan; ",Reflections on: KnowMore-Knowledge Base Augmentation with Structured Web Markup,,,,,,

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import pandas as pd

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
publications = pd.read_csv("/Users/bfetahu/Downloads/citations.csv", sep=",", header=0)
publications
# Out:
#                                               Authors  \
# 0   Nunes, Bernardo Pereira; Dietze, Stefan; Casan...
# 1     Taibi, Davide; Fetahu, Besnik; Dietze, Stefan;
# 2   Nunes, Bernardo Pereira; Mera, Alexander; Casa...
# 3   Nunes, B Pereira; Fetahu, Besnik; Casanova, Ma...
# 4   Fetahu, Besnik; Dietze, Stefan; Nunes, Bernard...
# 5   Nunes, Bernardo Pereira; Fetahu, Besnik; Dietz...
# 6   Nunes, Bernardo Pereira; Kawase, Ricardo; Feta...
# 7   Fetahu, Besnik; Dietze, Stefan; Nunes, Bernard...
# 8   Fetahu, Besnik; Pereira Nunes, Bernardo; Dietz...
# 9   Fetahu, Besnik; Nunes, Bernardo Pereira; Dietz...
# 10                   Fetahu, Besnik; Schenkel, Ralf;
# 11  Fetahu, Besnik; Dietze, Stefan; Nunes, Bernard...
# 12  Nunes, Bernardo Pereira; Kawase, Ricardo; Feta...
# 13  Nunes, Bernardo Pereira; Mera, Alexander; Kawa...
# 14  Fetahu, Besnik; Gadiraju, Ujwal; Dietze, Stefan;
# 15  Taibi, Davide; Dietze, Stefan; Fetahu, Besnik;...
# 16  Nunes, Bernardo Pereira; Fetahu, Besnik; Kawas...
# 17  Taibi, Davide; Chawla, Saniya; Dietze, Stefan;...
# 18  Taibi, Davide; Fulantelli, Giovanni; Dietze, S...
# 19  Fetahu, Besnik; Gadiraju, Ujwal; Dietze, Stefan;
# 20   Fetahu, Besnik; Anand, Abhijit; Anand, Avishek;
# 21   Fetahu, Besnik; Markert, Katja; Anand, Avishek;
# 22  Gadiraju, Ujwal; Siehndel, Patrick; Fetahu, Be...
# 23  Gadiraju, Ujwal; Fetahu, Besnik; Kawase, Ricar...
# 24  Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Diet...
# 25  Fetahu, Besnik; Dietze, Stefan; Nunes, Bernard...
# 26  Taibi, Davide; Fulantelli, Giovanni; Dietze, S...
# 27  Yu, Ran; Gadiraju, Ujwal; Zhu, Xiaofei; Fetahu...
# 28  Fetahu, Besnik; Markert, Katja; Nejdl, Wolfgan...
# 29  Yu, Ran; Fetahu, Besnik; Gadiraju, Ujwal; Diet...
# 30  Gadiraju, Ujwal; Fetahu, Besnik; Hube, Christo...
# 31  Taibi, Davide; Fulantelli, Giovanni; Dietze, S...
# 32  Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Diet...
# 33   Fetahu, Besnik; Markert, Katja; Anand, Avishek;
# 34  Gadiraju, Ujwal; Fetahu, Besnik; Kawase, Ricar...
# 35  d'Aquin, Mathieu; Adamou, Alessandro; Dietze, ...
# 36  Yu, Ran; Fetahu, Besnik; Gadiraju, Ujwal; Diet...
# 37  Hube, Christoph; Jäschke, Robert; Fetahu, Besn...
# 38                  Hube, Christoph; Fetahu, Besnik;
# 39                       Lyu, Lijun; Fetahu, Besnik;
# 40  Holtz, Peter; Fetahu, Besnik; Kimmerle, Joachim;
# 41  Chawla, S; Taibi, D; Dietze, S; Marenzi, I; Fe...
# 42  Yenikent, Seren; Buttliere, Brett; Fetahu, Bes...
# 43                                   Fetahu, Besnik;
# 44  Hube, Christoph; Fetahu, Besnik; Gadiraju, Ujw...
# 45                  Hube, Christoph; Fetahu, Besnik;
# 46  Hube, Christoph; Fetahu, Besnik; Gadiraju, Ujw...
# 47  Fetahu, Besnik; Anand, Avishek; Koutraki, Maria;
# 48  Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Lehm...
# 49                                   Fetahu, Besnik;
# 50  d’Aquin, Mathieu; Alessandro Adamou, A; Dietze...
# 51  Redi, Miriam; Fetahu, Besnik; Morgan, Jonathan...
# 52                 Holtz, P; Fetahu, B; Kimmerle, J;
# 53  Gottschalk, Simon; Tempelmeier, Nicolas; Knies...
# 54  Gottschalk, Simon; Tempelmeier, Nicolas; Knies...
# 55  Hube, Christoph; Idahl, Maximilian; Fetahu, Be...
# 56  Iosifidis, Vasileios; Fetahu, Besnik; Ntoutsi,...
# 57  Yu, Ran; Gadiraju, Ujwal; Fetahu, Besnik; Lehm...
#
#                                                 Title  \
# 0   Combining a co-occurrence-based and a semantic...
# 1   Towards integration of web data into a coheren...
# 2         Complex matching of rdf datatype properties
# 3   Cite4me: Semantic retrieval and analysis of sc...
# 4   Generating structured Profiles of Linked Data ...
# 5   Cite4Me: A Semantic Search and Retrieval Web A...
# 6     Interlinking documents based on semantic graphs
# 7   A Scalable Approach for Efficiently Generating...
# 8   Towards focused knowledge extraction: query-ba...
# 9   Summaries on the fly: Query-based extraction o...
# 10              Retrieval evaluation on focused tasks
# 11  What’s all the Data about?-Creating Structured...
# 12  Educational forums at a glance: Topic extracti...
# 13       A Topic Extraction Process for Online Forums
# 14  Crawl Me Maybe: Iterative Linked Dataset Prese...
# 15  Exploring type-specific topic profiles of data...
# 16  Interlinking Documents Based on Semantic Graph...
# 17   Exploring TED talks as linked data for education
# 18  Towards Analysing the Scope and Coverage of Ed...
# 19      Improving entity retrieval on structured data
# 20         How much is Wikipedia lagging behind news?
# 21  Automated News Suggestions for Populating Wiki...
# 22  Breaking Bad: Understanding Behavior of Crowd ...
# 23  Training workers for improving performance in ...
# 24           Adaptive Focused Crawling of Linked Data
# 25  Profiling of Linked Datasets using Structured ...
# 26  Educational Linked Data on the Web-Exploring a...
# 27  Towards entity summarisation on structured web...
# 28               Finding News Citations for Wikipedia
# 29  A Survey on Challenges for Entity Retrieval in...
# 30  Crystal clear or very vague? Effects of task c...
# 31  A Linked Data approach to evaluate Open Educat...
# 32  FuseM: query-centric data fusion on structured...
# 33  Fine Grained Citation Span for References in W...
# 34  Using worker self-assessments for competence-b...
# 35  AFEL: Towards Measuring Online Activities Cont...
# 36  A Survey on Challenges in Web Markup Data for ...
# 37      Towards Bias Detection in Online Text Corpora
# 38           Detecting biased statements in wikipedia
# 39  Real-time Event-based News Suggestion for Wiki...
# 40  Effects of contributor experience on the quali...
# 41   Exploring TED talks as linked data for education
# 42  Wikipedia article measures in relation to cont...
# 43  Approaches for Enriching and Improving Textual...
# 44  LimitBias! Measuring Worker Biases in the Crow...
# 45  Neural Based Statement Classification for Bias...
# 46  Understanding and mitigating worker biases in ...
# 47  TableNet: An Approach for Determining Fine-gra...
# 48  KnowMore–knowledge base augmentation with stru...
# 49  Approaches for enriching and improving textual...
# 50  The LinkedUp Data Catalogue: A Meta-Dataset of...
# 51  Citation Needed: A Taxonomy and Algorithmic As...
# 52                  Explore our sister journals here.
# 53  Simple-ML: Towards a Framework for Semantic Da...
# 54  Simple-ML: Towards a Framework for Semantic Da...
# 55  Debiasing Word Embeddings from Sentiment Assoc...
# 56           FAE: A Fairness-Aware Ensemble Framework
# 57  Reflections on: KnowMore-Knowledge Base Augmen...
#
#                                           Publication  Volume  Number  \
# 0                    Extended Semantic Web Conference     NaN     NaN
# 1   Proceedings of the 22nd International Conferen...     NaN     NaN
# 2   International Conference on Database and Exper...     NaN     NaN
# 3                                LAK (Data Challenge)   974.0     NaN
# 4   International Semantic Web Conference (Posters...     NaN     NaN
# 5   Proceedings of the ISWC 2013 Posters & Demonst...     NaN     NaN
# 6                           Procedia Computer Science    22.0     NaN
# 7   In Proceedings of the 11th Extended Semantic W...     NaN     NaN
# 8   Proceedings of the 22nd International Conferen...     NaN     NaN
# 9         International Conference on Web Engineering     NaN     NaN
# 10  Proceedings of the 35th international ACM SIGI...     NaN     NaN
# 11  Proceedings of the companion publication of th...     NaN     NaN
# 12  International Conference on Web Information Sy...     NaN     NaN
# 13  Advanced Learning Technologies (ICALT), 2014 I...     NaN     NaN
# 14  International Semantic Web Conference (Posters...     NaN     NaN
# 15                                                NaN     NaN     NaN
# 16    Knowledge-Based Information Systems in Practice     NaN     NaN
# 17          British Journal of Educational Technology    46.0     5.0
# 18                                                NaN     NaN     NaN
# 19              International Semantic Web Conference     NaN     NaN
# 20      Proceedings of the ACM Web Science Conference     NaN     NaN
# 21  Proceedings of the 24th ACM International on C...     NaN     NaN
# 22  Proceedings of the 26th ACM Conference on Hype...     NaN     NaN
# 23  Design for Teaching and Learning in a Networke...     NaN     NaN
# 24  International Conference on Web Information Sy...     NaN     NaN
# 25  The 12th International Semantic Web Conference...     NaN     NaN
# 26                            Open Data for Education     NaN     NaN
# 27                   European Semantic Web Conference     NaN     NaN
# 28  Proceedings of the 25th ACM International on C...     NaN     NaN
# 29                          CEUR Workshop Proceedings  1690.0     NaN
# 30  1st International Workshop on Weaving Relation...     NaN     NaN
# 31  Proceedings of the 2013 International Conferen...     NaN     NaN
# 32  2017 IEEE 33rd International Conference on Dat...     NaN     NaN
# 33                    arXiv preprint arXiv:1707.07278     NaN     NaN
# 34  ACM Transactions on Computer-Human Interaction...    24.0     4.0
# 35                                      ARTEL@ EC-TEL     NaN     NaN
# 36  International Semantic Web Conference (Posters...     NaN     NaN
# 37             Jo Bates Paul D. Clough Robert Jäschke     NaN     NaN
# 38  Companion Proceedings of the The Web Conferenc...     NaN     NaN
# 39  Companion Proceedings of the The Web Conferenc...     NaN     NaN
# 40               Journal of medical Internet research    20.0     5.0
# 41                                                NaN     NaN     NaN
# 42  7th International Workshop on Learning and Edu...     NaN     NaN
# 43                    arXiv preprint arXiv:1804.07583     NaN     NaN
# 44                                                NaN     NaN     NaN
# 45  Proceedings of the Twelfth ACM International C...     NaN     NaN
# 46  Proceedings of the 2019 CHI Conference on Huma...     NaN     NaN
# 47                      The World Wide Web Conference     NaN     NaN
# 48                                       Semantic Web    10.0     1.0
# 49                                                NaN     NaN     NaN
# 50  Semantic Web–Interoperability, Usability, Appl...     NaN     NaN
# 51                      The World Wide Web Conference     NaN     NaN
# 52                                 J Med Internet Res    20.0     5.0
# 53       International Conference on Semantic Systems     NaN     NaN
# 54       International Conference on Semantic Systems     NaN     NaN
# 55  Proceedings of the 13th International Conferen...     NaN     NaN
# 56  2019 IEEE International Conference on Big Data...     NaN     NaN
# 57                                                NaN     NaN     NaN
#
#         Pages    Year                                          Publisher
# 0     548-562  2013.0                         Springer Berlin Heidelberg
# 1     419-424  2013.0                                                ACM
# 2     195-208  2013.0                       Springer, Berlin, Heidelberg
# 3         NaN  2013.0                                                NaN
# 4     113-116  2013.0                                                NaN
# 5         NaN  2013.0                                                NaN
# 6     231-240  2013.0                                           Elsevier
# 7         NaN  2014.0                                           Springer
# 8       77-78  2013.0                                                NaN
# 9     249-264  2013.0                         Springer Berlin Heidelberg
# 10  1135-1136  2012.0                                                ACM
# 11    261-262  2014.0  International World Wide Web Conferences Steer...
# 12    351-364  2014.0                                     Springer, Cham
# 13    541-543  2014.0                                               IEEE
# 14    433-436  2014.0                                                NaN
# 15        NaN  2011.0                                                NaN
# 16    139-155  2015.0                  Springer International Publishing
# 17  1092-1096  2015.0                                                NaN
# 18        NaN     NaN                                                NaN
# 19    474-491  2015.0                  Springer International Publishing
# 20        1-9  2015.0                                                NaN
# 21    323-332  2015.0                                                ACM
# 22      33-38  2015.0                                                ACM
# 23    100-114  2015.0                                     Springer, Cham
# 24    554-569  2015.0                  Springer International Publishing
# 25        NaN  2013.0                                                NaN
# 26      16-37  2016.0                  Springer International Publishing
# 27      69-73  2016.0                                     Springer, Cham
# 28    337-346  2016.0                                                ACM
# 29        NaN  2016.0                                                NaN
# 30        NaN  2016.0                                                NaN
# 31    154-157  2013.0                                                NaN
# 32    179-182  2017.0                                               IEEE
# 33        NaN  2017.0                                                NaN
# 34       1-26  2017.0                              ACM New York, NY, USA
# 35        NaN  2017.0                                                NaN
# 36      17-21  2016.0                                                NaN
# 37         19     NaN                                                NaN
# 38  1779-1786  2018.0  International World Wide Web Conferences Steer...
# 39  1793-1799  2018.0  International World Wide Web Conferences Steer...
# 40       e171  2018.0            JMIR Publications Inc., Toronto, Canada
# 41        NaN  2015.0          British Journal of Educational Technology
# 42        5-8  2018.0  Association for Computing Machinery Amsterdam,...
# 43        NaN  2018.0                                                NaN
# 44        NaN  2018.0                                                NaN
# 45    195-203  2019.0                                                ACM
# 46       1-12  2019.0                                                NaN
# 47  2736-2742  2019.0                                                NaN
# 48    159-180  2019.0                                          IOS Press
# 49        NaN  2017.0  Hannover: Gottfried Wilhelm Leibniz Universitä...
# 50        NaN  2014.0                                                NaN
# 51  1567-1578  2019.0                                                ACM
# 52       e171  2018.0                                                NaN
# 53    359-366  2019.0                                     Springer, Cham
# 54    359-366  2019.0                                     Springer, Cham
# 55    259-267  2020.0                                                NaN
# 56  1375-1380  2019.0                                               IEEE
# 57        NaN     NaN                                                NaN

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
import os
for row, item in publications.iterrows():
    
    md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
    html_filename = str(item.pub_date) + "-" + item.url_slug
    year = item.pub_date[:4]
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item.title + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
    if len(str(item.excerpt)) > 5:
        md += "\nexcerpt: '" + html_escape(item.excerpt) + "'"
    
    md += "\ndate: " + str(item.pub_date) 
    
    md += "\nvenue: '" + html_escape(item.venue) + "'"
    
    if len(str(item.paper_url)) > 5:
        md += "\npaperurl: '" + item.paper_url + "'"
    
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    
    md += "\n---"
    
    ## Markdown description for individual page
        
    if len(str(item.excerpt)) > 5:
        md += "\n" + html_escape(item.excerpt) + "\n"
    
    if len(str(item.paper_url)) > 5:
        md += "\n[Download paper here](" + item.paper_url + ")\n" 
        
    md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-592da968cbd3> in <module>
#       2 for row, item in publications.iterrows():
#       3
# ----> 4     md_filename = str(item.pub_date) + "-" + item.url_slug + ".md"
#       5     html_filename = str(item.pub_date) + "-" + item.url_slug
#       6     year = item.pub_date[:4]
#
# /Library/Python/3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'pub_date'

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# 2009-10-01-paper-title-number-1.md  2015-10-01-paper-title-number-3.md
# 2010-10-01-paper-title-number-2.md

# %%
# !cat ../_publications/2009-10-01-paper-title-number-1.md
# Out:
# ---
# title: "Paper Title Number 1"
# collection: publications
# permalink: /publication/2009-10-01-paper-title-number-1
# excerpt: 'This paper is about the number 1. The number 2 is left for future work.'
# date: 2009-10-01
# venue: 'Journal 1'
# paperurl: 'http://academicpages.github.io/files/paper1.pdf'
# citation: 'Your Name, You. (2009). &quot;Paper Title Number 1.&quot; <i>Journal 1</i>. 1(1).'
# ---
# This paper is about the number 1. The number 2 is left for future work.
#
# [Download paper here](http://academicpages.github.io/files/paper1.pdf)
#
# Recommended citation: Your Name, You. (2009). "Paper Title Number 1." <i>Journal 1</i>. 1(1).
